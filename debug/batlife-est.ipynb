# %%
import pandas as pd

# %%
df = pd.read_csv("final.csv")

# %%
df[df["STATUS"] == "Not-charging"]
# Out:
#           DATE      TIME      STATE       DEVTYPE  NAME   SOURCE  \
# 249   02/10/25  07:39:48  Suspended  power_supply  BAT0  Battery
# 360   02/03/25  18:08:00  Suspended  power_supply  BAT0  Battery
# 727   01/12/25  20:16:50     Active  power_supply  BAT0  Battery
# 748   01/12/25  12:00:15     Active  power_supply  BAT0  Battery
# 904   01/08/25  18:53:00  Suspended  power_supply  BAT0  Battery
# 2282  11/09/24  22:33:03     Active  power_supply  BAT0  Battery
#
#             STATUS  PRESENT TECHNOLOGY  CYCLE_COUNT  ...  VOLTAGE_NOW  \
# 249   Not-charging        1     Li-ion            0  ...     11822000
# 360   Not-charging        1     Li-ion            0  ...     11226000
# 727   Not-charging        1     Li-ion            0  ...     11583000
# 748   Not-charging        1     Li-ion            0  ...     11414000
# 904   Not-charging        1     Li-ion            0  ...     12017000
# 2282  Not-charging        1     Li-ion            0  ...     12120000
#
# ...
